# %%
from FaceEmbedding import *
from glob import glob
import cv2
from matplotlib import pyplot as plt
import random as rand

# %%
face_embedding_model = FaceEmbedding()
# Out:
# /home/dell/miniconda3/envs/llm/lib/python3.10/site-packages/torchvision/transforms/v2/_deprecated.py:41: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.
#   warnings.warn(

# %%
imgs = glob('testing_images/*')
imgs
# Out:
# ['testing_images/Screenshot from 2024-05-22 20-24-21.png',
#  'testing_images/Screenshot from 2024-05-22 20-20-35.png',
#  'testing_images/Screenshot from 2024-05-22 20-24-33.png',
#  'testing_images/Screenshot from 2024-05-22 20-21-13.png',
#  'testing_images/people.jpeg',
#  'testing_images/Screenshot from 2024-05-22 20-22-32.png',
#  'testing_images/Screenshot from 2024-05-22 20-23-41.png',
#  'testing_images/Screenshot from 2024-05-22 20-22-07.png',
#  'testing_images/Screenshot from 2024-05-22 20-25-06.png',
#  'testing_images/Screenshot from 2024-05-22 20-21-23.png',
#  'testing_images/Screenshot from 2024-05-22 20-26-39.png',
#  'testing_images/Screenshot from 2024-05-22 20-19-10.png',
#  'testing_images/Screenshot from 2024-05-22 20-16-56.png',
#  'testing_images/Screenshot from 2024-05-22 20-20-23.png',
#  'testing_images/Screenshot from 2024-05-22 20-20-54.png',
#  'testing_images/Screenshot from 2024-05-22 20-24-02.png',
# ...

# %%
rand.shuffle(imgs)

# %%
imgs
# Out:
# ['testing_images/Screenshot from 2024-05-22 20-20-35.png',
#  'testing_images/Screenshot from 2024-05-22 20-24-21.png',
#  'testing_images/people.jpeg',
#  'testing_images/Screenshot from 2024-05-22 20-21-13.png',
#  'testing_images/Screenshot from 2024-05-22 20-16-56.png',
#  'testing_images/Screenshot from 2024-05-22 20-26-39.png',
#  'testing_images/Screenshot from 2024-05-22 20-22-07.png',
#  'testing_images/Screenshot from 2024-05-22 20-19-10.png',
#  'testing_images/Screenshot from 2024-05-22 20-22-32.png',
#  'testing_images/Screenshot from 2024-05-22 20-23-41.png',
#  'testing_images/Screenshot from 2024-05-22 20-24-02.png',
#  'testing_images/Screenshot from 2024-05-22 20-25-06.png',
#  'testing_images/Screenshot from 2024-05-22 20-24-33.png',
#  'testing_images/Screenshot from 2024-05-22 20-20-54.png',
#  'testing_images/Screenshot from 2024-05-22 20-21-23.png',
#  'testing_images/Screenshot from 2024-05-22 20-27-03.png',
# ...

# %%
for img in imgs:
    img = cv2.imread(img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    EucEmb, FREmb, face_locations = face_embedding_model.makeEmbeddings(img, 2)
    break
# Out:
# [(101, 285, 153, 233)]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(img)
# ----> 5 EucEmb, FREmb, face_locations = face_embedding_model.makeEmbeddings(img, 2)
#       6 break
#
# File ~/nruh/llm_chatbot/FaceEmbedding.py:135, in FaceEmbedding.makeEmbeddings(self, img, k)
#     133 for face in face_locations:
#     134     face_img = img[face[0]:face[2], face[1]:face[3]]
# --> 135     Euc = self.__makeEucEmbeddings(face_img)
#     136     print(Euc.shape())
#     137     EucEmb.append(Euc.to_list())
#
# File ~/nruh/llm_chatbot/FaceEmbedding.py:119, in FaceEmbedding.__makeEucEmbeddings(self, img)
#     118 def __makeEucEmbeddings(self, img)->np.ndarray:
# --> 119     img_t = self.T(img)
#     120     img_t = torch.unsqueeze(img_t, dim=0)
# ...

# %%
plt.imshow(img)
